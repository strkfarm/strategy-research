# %% [markdown]
# # Concentrated liquidity: Fee earned versus IL
#
# Liquidity rebalancing
# https://atise.medium.com/liquidity-provider-strategies-for-uniswap-liquidity-rebalancing-f4430eec63a0
#
# Liquidity rebalancing or relocation refers to moving the liquidity around to a different price boundaries. It’s typically used to move out-of-range LP positions back into the range, where the active price is.

# %%
# !pip install giza-datasets
# Out:
# Requirement already satisfied: giza-datasets in c:\users\molak\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: gcsfs<2024.0.0,>=2023.12.2.post1 in c:\users\molak\anaconda3\lib\site-packages (from giza-datasets) (2023.12.2.post1)
# Requirement already satisfied: polars<1,>=0 in c:\users\molak\anaconda3\lib\site-packages (from giza-datasets) (0.19.19)
# Requirement already satisfied: pyarrow<16,>=15 in c:\users\molak\anaconda3\lib\site-packages (from giza-datasets) (15.0.2)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\molak\anaconda3\lib\site-packages (from giza-datasets) (2.7.1)
# Requirement already satisfied: rich<14,>=13 in c:\users\molak\anaconda3\lib\site-packages (from giza-datasets) (13.3.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\molak\anaconda3\lib\site-packages (from gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (3.9.3)
# Requirement already satisfied: decorator>4.1.2 in c:\users\molak\anaconda3\lib\site-packages (from gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (5.1.1)
# Requirement already satisfied: fsspec==2023.12.2 in c:\users\molak\anaconda3\lib\site-packages (from gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2023.12.2)
# Requirement already satisfied: google-auth>=1.2 in c:\users\molak\anaconda3\lib\site-packages (from gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\molak\anaconda3\lib\site-packages (from gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (1.2.0)
# Requirement already satisfied: google-cloud-storage in c:\users\molak\anaconda3\lib\site-packages (from gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2.16.0)
# Requirement already satisfied: requests in c:\users\molak\anaconda3\lib\site-packages (from gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.16.6 in c:\users\molak\anaconda3\lib\site-packages (from pyarrow<16,>=15->giza-datasets) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\molak\anaconda3\lib\site-packages (from pydantic<3,>=2->giza-datasets) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\molak\anaconda3\lib\site-packages (from pydantic<3,>=2->giza-datasets) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\molak\anaconda3\lib\site-packages (from pydantic<3,>=2->giza-datasets) (4.9.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\molak\anaconda3\lib\site-packages (from rich<14,>=13->giza-datasets) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\molak\anaconda3\lib\site-packages (from rich<14,>=13->giza-datasets) (2.15.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\molak\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\molak\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\molak\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\molak\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\molak\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (1.9.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\molak\anaconda3\lib\site-packages (from google-auth>=1.2->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\molak\anaconda3\lib\site-packages (from google-auth>=1.2->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\molak\anaconda3\lib\site-packages (from google-auth>=1.2->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (4.9)
# Requirement already satisfied: mdurl~=0.1 in c:\users\molak\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=13->giza-datasets) (0.1.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\molak\anaconda3\lib\site-packages (from google-auth-oauthlib->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in c:\users\molak\anaconda3\lib\site-packages (from google-cloud-storage->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2.19.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\molak\anaconda3\lib\site-packages (from google-cloud-storage->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\molak\anaconda3\lib\site-packages (from google-cloud-storage->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\molak\anaconda3\lib\site-packages (from google-cloud-storage->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\molak\anaconda3\lib\site-packages (from requests->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\molak\anaconda3\lib\site-packages (from requests->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\molak\anaconda3\lib\site-packages (from requests->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\molak\anaconda3\lib\site-packages (from requests->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (2024.2.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\molak\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\molak\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\molak\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (1.23.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\molak\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\molak\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs<2024.0.0,>=2023.12.2.post1->giza-datasets) (3.2.2)

# %%
import yfinance as yf
import math
import numpy as np
import pandas as pd
from giza.datasets import DatasetsLoader
from giza.datasets import DatasetsHub
hub = DatasetsHub()

hub.show()
# Out:
#                            Datasets
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Dataset Name                                               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ tvl-fee-per-protocol                                       │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens                                     │
# ├────────────────────────────────────────────────────────────┤
# │ tokens-ohcl                                                │
# ├────────────────────────────────────────────────────────────┤
# │ top-pools-apy-per-protocol                                 │
# ├────────────────────────────────────────────────────────────┤
# │ tokens-daily-prices-mcap-volume                            │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=aave-v2                     │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=aave-v3                     │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=aura                        │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=balancer-v2                 │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=beefy                       │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=benqi-lending               │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=coinwind                    │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=compound-v2                 │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=convex-finance              │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=curve-dex                   │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=flamincome                  │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=lido                        │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=pancakeswap-amm             │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=pendle                      │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=rocket-pool                 │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=sushiswap                   │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=uniswap-v2                  │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=uniswap-v3                  │
# ├────────────────────────────────────────────────────────────┤
# │ tvl-per-project-tokens/project=yearn-finance               │
# ├────────────────────────────────────────────────────────────┤
# │ aave-daily-deposits-borrowsv2                              │
# ├────────────────────────────────────────────────────────────┤
# │ aave-daily-deposits-borrowsv3                              │
# ├────────────────────────────────────────────────────────────┤
# │ aave-daily-rates-indexes                                   │
# ├────────────────────────────────────────────────────────────┤
# │ aave-liquidationsV2                                        │
# ├────────────────────────────────────────────────────────────┤
# │ aave-liquidationsV3                                        │
# ├────────────────────────────────────────────────────────────┤
# │ balancer-daily-pool-liquidity                              │
# ├────────────────────────────────────────────────────────────┤
# │ balancer-daily-swap-fees                                   │
# ├────────────────────────────────────────────────────────────┤
# │ balancer-daily-trade-volume                                │
# ├────────────────────────────────────────────────────────────┤
# │ yearn-individual-deposits                                  │
# ├────────────────────────────────────────────────────────────┤
# │ yearn-individual-withdraws                                 │
# ├────────────────────────────────────────────────────────────┤
# │ yearn-strategy-borrows                                     │
# ├────────────────────────────────────────────────────────────┤
# │ yearn-strategy-returns                                     │
# ├────────────────────────────────────────────────────────────┤
# │ compound-daily-interest-rates                              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pools-info                              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-arkm-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-arkm-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pdt-prime-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pdt-prime-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-halal-3000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-halal-3000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-send-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-send-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-babyrfd-weth-10000-liquidity-snapshots  │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-babyrfd-weth-10000-current-ticks        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-our-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-our-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-fldx-usdc-500-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-fldx-usdc-500-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-blur-usdc-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-blur-usdc-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-cdt-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-cdt-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-liquidator-weth-100-current-ticks       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-liquidator-weth-100-liquidity-snapshots │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-aave-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-aave-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wooo-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wooo-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rng-lpt-3000-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rng-lpt-3000-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-par-usdc-500-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-par-usdc-500-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-sifum-usdt-10000-liquidity-snapshots    │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-sifum-usdt-10000-current-ticks          │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-spot-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-spot-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-xen-weth-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-xen-weth-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-qanx-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-qanx-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pepe3r-weth-100-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pepe3r-weth-100-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-hex-usdc-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-hex-usdc-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-temp-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-temp-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-weth-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-weth-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ben-weth-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ben-weth-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pet-weth-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pet-weth-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rng-link-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rng-link-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-prime-weth-3000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-prime-weth-3000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-nftx-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-nftx-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ldo-weth-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ldo-weth-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-steth-weth-10000-current-ticks          │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-steth-weth-10000-liquidity-snapshots    │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-orc-weth-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-orc-weth-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dust-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dust-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-ant-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-ant-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-mnt-weth-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-mnt-weth-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-blur-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-blur-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-zusd-500-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-zusd-500-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-fpi-frax-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-fpi-frax-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-ela-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-ela-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-crv-crvusd-3000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-crv-crvusd-3000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-shib-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-shib-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdd-usdt-100-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdd-usdt-100-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-usdc-500-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-usdc-500-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-badger-weth-10000-current-ticks         │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-badger-weth-10000-liquidity-snapshots   │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-lusd-usdc-500-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-lusd-usdc-500-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wsteth-usdc-3000-liquidity-snapshots    │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wsteth-usdc-3000-current-ticks          │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-eul-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-eul-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-brz-usdt-100-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-brz-usdt-100-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-yfi-weth-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-yfi-weth-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-weth-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-weth-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-arb-weth-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-arb-weth-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rng-weth-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rng-weth-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frxeth-frax-10000-liquidity-snapshots   │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frxeth-frax-10000-current-ticks         │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-crv-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-crv-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-cream-weth-10000-liquidity-snapshots    │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-cream-weth-10000-current-ticks          │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-link-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-link-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pepe-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pepe-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-mim-usdc-500-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-mim-usdc-500-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-mim-usdc-500-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-mim-usdc-500-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-wsteth-500-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-wsteth-500-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-tbtc-wbtc-500-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-tbtc-wbtc-500-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frxeth-weth-500-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frxeth-weth-500-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wsteth-weth-100-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wsteth-weth-100-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-lusd-usdc-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-lusd-usdc-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdd-mim-100-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdd-mim-100-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-gohm-usdc-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-gohm-usdc-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wsteth-weth-500-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wsteth-weth-500-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-psyop-weth-3000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-psyop-weth-3000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-1inch-usdc-10000-liquidity-snapshots    │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-1inch-usdc-10000-current-ticks          │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dydx-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dydx-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-olas-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-olas-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-crvusd-500-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-crvusd-500-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-nexo-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-nexo-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-1inch-weth-10000-current-ticks          │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-1inch-weth-10000-liquidity-snapshots    │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-usdc-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-usdc-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-frax-500-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-frax-500-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-trac-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-trac-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-lqty-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-lqty-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ldo-weth-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ldo-weth-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rai-dai-500-current-ticks               │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rai-dai-500-liquidity-snapshots         │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-sol-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-sol-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frax-usdc-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frax-usdc-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-glo-usdt-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-glo-usdt-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pepe-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-pepe-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ageur-usdc-100-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ageur-usdc-100-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-usdt-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-usdt-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-weth-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-weth-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ocean-weth-3000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ocean-weth-3000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-weth-500-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-weth-500-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-inj-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-inj-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-index-weth-10000-liquidity-snapshots    │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-index-weth-10000-current-ticks          │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-usdt-500-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-usdt-500-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-sweth-100-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-sweth-100-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-ens-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-ens-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-lqty-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-lqty-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-link-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-link-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-usdt-100-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-usdt-100-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-sweth-500-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-sweth-500-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-usdt-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-usdt-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-bob-weth-500-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-bob-weth-500-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frax-alusd-500-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frax-alusd-500-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rare-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rare-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-usdt-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-usdt-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-usdt-500-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-usdt-500-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-weth-500-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-weth-500-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-chz-usdt-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-chz-usdt-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-xdefi-weth-10000-liquidity-snapshots    │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-xdefi-weth-10000-current-ticks          │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rbn-weth-10000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rbn-weth-10000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-matic-weth-3000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-matic-weth-3000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-bob-usdt-100-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-bob-usdt-100-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-usdc-500-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-usdc-500-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-usdt-500-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-usdt-500-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ape-weth-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ape-weth-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frax-fpis-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-frax-fpis-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rbn-usdc-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-rbn-usdc-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-rng-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-wbtc-rng-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-usdt-10000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-usdt-10000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-babywojak-weth-3000-current-ticks       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-babywojak-weth-3000-liquidity-snapshots │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ageur-weth-500-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-ageur-weth-500-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-blur-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-blur-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-cvx-crv-10000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-cvx-crv-10000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-usdc-100-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-usdc-100-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-usdt-100-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-dai-usdt-100-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-gohm-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-gohm-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-vega-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-weth-vega-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-gbtc-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-gbtc-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-comp-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-comp-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-usdc-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-usdc-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-euroe-usdc-500-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-euroe-usdc-500-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-reth-weth-500-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-reth-weth-500-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-gamma-weth-3000-current-ticks           │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-gamma-weth-3000-liquidity-snapshots     │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-aave-weth-3000-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-aave-weth-3000-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-arb-weth-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-arb-weth-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-lusd-blusd-500-liquidity-snapshots      │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-lusd-blusd-500-current-ticks            │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-cdai-dai-500-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-cdai-dai-500-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-bob-100-liquidity-snapshots        │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-usdc-bob-100-current-ticks              │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-wbtc-3000-current-ticks             │
# ├────────────────────────────────────────────────────────────┤
# │ uniswapv3-ethereum-uni-wbtc-3000-liquidity-snapshots       │
# ├────────────────────────────────────────────────────────────┤
# │ farcaster-casts                                            │
# ├────────────────────────────────────────────────────────────┤
# │ farcaster-links                                            │
# ├────────────────────────────────────────────────────────────┤
# │ farcaster-reactions                                        │
# ├────────────────────────────────────────────────────────────┤
# │ lens-posts                                                 │
# ├────────────────────────────────────────────────────────────┤
# │ lens-mirrors                                               │
# ├────────────────────────────────────────────────────────────┤
# │ lens-comments                                              │
# ├────────────────────────────────────────────────────────────┤
# │ lens-quotes                                                │
# ├────────────────────────────────────────────────────────────┤
# │ pancakeswap-daily-volume                                   │
# ├────────────────────────────────────────────────────────────┤
# │ curve-daily-volume-fees                                    │
# ├────────────────────────────────────────────────────────────┤
# │ gora-competition-training                                  │
# ├────────────────────────────────────────────────────────────┤
# │ gora-competition-evaluation                                │
# └────────────────────────────────────────────────────────────┘

# %%
# Define the time period for historical data
start_date = '2024-02-22'
end_date = '2024-05-22'

# Fetch historical data for ETH and STRK
eth_data = yf.download('ETH-USD', start=start_date, end=end_date, interval='1d')
strk_data = yf.download('STRK22691-USD', start=start_date, end=end_date, interval='1d')

# Display the first few rows of each dataset
print("ETH Data:")
print(eth_data.head())
print("\nSTRK Data:")
print(strk_data.head())

# Usage example:
loader = DatasetsLoader()

liquidity_df = loader.load('uniswapv3-ethereum-wbtc-wsteth-500-liquidity-snapshots')
ticks_df = loader.load('uniswapv3-ethereum-wbtc-wsteth-500-current-ticks')
pools_info_df = loader.load('uniswapv3-ethereum-pools-info')

liquidity_df.head()
ticks_df.head()
pools_info_df.head()

# Display the first few rows of each DataFrame
print("Liquidity Snapshots:")
print(liquidity_df.head())

print("\nCurrent Ticks:")
print(ticks_df.head())

print("\nPools Info:")
print(pools_info_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ETH Data:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-02-22  2969.599854  3030.666016  2907.109375  2971.007324  2971.007324
# 2024-02-23  2970.139648  2991.329590  2906.583740  2921.658203  2921.658203
# 2024-02-24  2921.962891  3003.195068  2907.700684  2992.385986  2992.385986
# 2024-02-25  2992.366699  3117.428955  2984.393066  3112.697266  3112.697266
# 2024-02-26  3112.529053  3197.375000  3037.954590  3178.993652  3178.993652
#
#                  Volume
# Date
# 2024-02-22  18058908246
# 2024-02-23  12822717059
# 2024-02-24  10701688842
# 2024-02-25  14620450464
# 2024-02-26  17504464351
#
# STRK Data:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2024-02-22  1.897438  2.014914  1.805397  1.920013   1.920013  652017969
# 2024-02-23  1.922879  2.173839  1.863164  1.927956   1.927956  854674677
# 2024-02-24  1.927188  1.956111  1.865331  1.897052   1.897052  317884696
# 2024-02-25  1.896999  1.953578  1.879705  1.951373   1.951373  275816651
# 2024-02-26  1.949746  2.007316  1.862171  1.970862   1.970862  376138798
# Dataset read from cache.
# Loading dataset uniswapv3-ethereum-wbtc-wsteth-500-liquidity-snapshots from cache.
# Dataset read from cache.
# Loading dataset uniswapv3-ethereum-wbtc-wsteth-500-current-ticks from cache.
# Dataset read from cache.
# Loading dataset uniswapv3-ethereum-pools-info from cache.
# Liquidity Snapshots:
# shape: (5, 6)
# ┌──────────────┬──────────┬───────────┬───────────┬──────────┬─────────┐
# │ block_number ┆ in_token ┆ out_token ┆ price     ┆ amount   ┆ tick_id │
# │ ---          ┆ ---      ┆ ---       ┆ ---       ┆ ---      ┆ ---     │
# │ i64          ┆ str      ┆ str       ┆ f64       ┆ f64      ┆ i64     │
# ╞══════════════╪══════════╪═══════════╪═══════════╪══════════╪═════════╡
# │ 18031098     ┆ WBTC     ┆ wstETH    ┆ 14.066071 ┆ 1.931784 ┆ 256700  │
# │ 18031098     ┆ WBTC     ┆ wstETH    ┆ 14.053418 ┆ 2.145407 ┆ 256690  │
# │ 18031098     ┆ WBTC     ┆ wstETH    ┆ 14.039373 ┆ 2.144335 ┆ 256680  │
# │ 18031098     ┆ WBTC     ┆ wstETH    ┆ 14.025341 ┆ 2.143263 ┆ 256670  │
# │ 18031098     ┆ WBTC     ┆ wstETH    ┆ 14.011323 ┆ 2.142192 ┆ 256660  │
# └──────────────┴──────────┴───────────┴───────────┴──────────┴─────────┘
#
# Current Ticks:
# shape: (5, 2)
# ┌──────────────┬──────────────┐
# │ current_tick ┆ block_number │
# │ ---          ┆ ---          │
# │ i64          ┆ i64          │
# ╞══════════════╪══════════════╡
# │ 256624       ┆ 17972098     │
# │ 256470       ┆ 17962098     │
# │ 256693       ┆ 18023098     │
# │ 256709       ┆ 18033098     │
# │ 256573       ┆ 17996098     │
# └──────────────┴──────────────┘
#
# Pools Info:
# shape: (5, 11)
# ┌─────────────┬────────────┬─────────┬────────┬───┬────────────┬────────────┬──────────┬───────────┐
# │ address     ┆ tick_spaci ┆ token0  ┆ token1 ┆ … ┆ token0_add ┆ token1_add ┆ chain    ┆ pool_type │
# │ ---         ┆ ng         ┆ ---     ┆ ---    ┆   ┆ ress       ┆ ress       ┆ ---      ┆ ---       │
# │ str         ┆ ---        ┆ str     ┆ str    ┆   ┆ ---        ┆ ---        ┆ str      ┆ str       │
# │             ┆ i64        ┆         ┆        ┆   ┆ str        ┆ str        ┆          ┆           │
# ╞═════════════╪════════════╪═════════╪════════╪═══╪════════════╪════════════╪══════════╪═══════════╡
# │ 0xf3e996148 ┆ 200        ┆ PDT     ┆ PRIME  ┆ … ┆ 0x375aBB85 ┆ 0xb23d80f5 ┆ ethereum ┆ UniswapV3 │
# │ 839df04153c ┆            ┆         ┆        ┆   ┆ C329753b1B ┆ FefcDDaa21 ┆          ┆           │
# │ 70865cff12… ┆            ┆         ┆        ┆   ┆ a849a60143 ┆ 2212F02802 ┆          ┆           │
# │             ┆            ┆         ┆        ┆   ┆ 8A…        ┆ 1B…        ┆          ┆           │
# │ 0xfc46b56b5 ┆ 60         ┆ WETH    ┆ HALAL  ┆ … ┆ 0xC02aaA39 ┆ 0xf17E0fC7 ┆ ethereum ┆ UniswapV3 │
# │ 92295585911 ┆            ┆         ┆        ┆   ┆ b223FE8D0A ┆ D58088C0dc ┆          ┆           │
# │ 5337a06e5d… ┆            ┆         ┆        ┆   ┆ 0e5C4F27eA ┆ 2Eb548C940 ┆          ┆           │
# │             ┆            ┆         ┆        ┆   ┆ D9…        ┆ 12…        ┆          ┆           │
# │ 0x14f59c715 ┆ 200        ┆ send    ┆ WETH   ┆ … ┆ 0x3f14920c ┆ 0xC02aaA39 ┆ ethereum ┆ UniswapV3 │
# │ c205002c6e3 ┆            ┆         ┆        ┆   ┆ 99BEB920Af ┆ b223FE8D0A ┆          ┆           │
# │ f36766d302… ┆            ┆         ┆        ┆   ┆ a163031c4e ┆ 0e5C4F27eA ┆          ┆           │
# │             ┆            ┆         ┆        ┆   ┆ 47…        ┆ D9…        ┆          ┆           │
# │ 0x8d7e5ffcf ┆ 200        ┆ BABYRFD ┆ WETH   ┆ … ┆ 0x3C7a21Cb ┆ 0xC02aaA39 ┆ ethereum ┆ UniswapV3 │
# │ 43fef6a939b ┆            ┆         ┆        ┆   ┆ 00569CA807 ┆ b223FE8D0A ┆          ┆           │
# │ a855ce5611… ┆            ┆         ┆        ┆   ┆ cA4f1F4cf6 ┆ 0e5C4F27eA ┆          ┆           │
# │             ┆            ┆         ┆        ┆   ┆ c5…        ┆ D9…        ┆          ┆           │
# │ 0x3b7b9616f ┆ 60         ┆ USDC    ┆ OUR    ┆ … ┆ 0xA0b86991 ┆ 0xA2887163 ┆ ethereum ┆ UniswapV3 │
# │ 30a52cdedb9 ┆            ┆         ┆        ┆   ┆ c6218b36c1 ┆ 633612a052 ┆          ┆           │
# │ 73515e415e… ┆            ┆         ┆        ┆   ┆ d19D4a2e9E ┆ 6Dc51E666D ┆          ┆           │
# │             ┆            ┆         ┆        ┆   ┆ b0…        ┆ 7d…        ┆          ┆           │
# └─────────────┴────────────┴─────────┴────────┴───┴────────────┴────────────┴──────────┴───────────┘

# %% [markdown]
# Protocol: MySwap
# Pool: ETH-STRK
#
# Assuming u would contribute liquidity to a price range of +-5% of current price, What would be my returns in a time period of 3 months from fees.
#
# Risk: Impermanent loss (IL). Within a given price range of ur liquidity, say current price is 3000 and u invest between 2850 and 3150 in the pool. As price moves from 3000 to up or down, u will get something called IL.
#
# But as swaps happen, u also earn fees as long as price is within this range. When price moves out of this range, ur simulation shall re-adjust position to new current price. e.g. if price moves to 2850, u rebalance here to be +-5% based on this price. The amount used to rebalance will be ur total available amount during the rebalance time. This is dependent on how much fees u earn vs how much u lost in IL.
#
# There are more minute details, i want u to digest this so far and have an high level approach to solve this

# %%
# Assuming eth_data and strk_data are already fetched

# Parameters
price_range = 0.05  # ±5%
initial_liquidity = 10  # Initial liquidity provided in ETH
trading_volume_per_day = 1000000  # Average daily trading volume in the pool
fee_percentage = 0.003  # 0.3% fee
time_period_days = len(eth_data)  # Use the length of the fetched data
print(time_period_days)

# Function to calculate impermanent loss 
# derivation: https://medium.com/auditless/how-to-calculate-impermanent-loss-full-derivation-803e8b2497b7
def impermanent_loss(price_ratio):
    return 2 * (np.sqrt(price_ratio) / (1 + price_ratio)) - 1
def impermanent_loss(r):
    return 1 - math.sqrt((4 * r) / ((r + 1) ** 2))

# Initialize variables
fees_earned = 0
impermanent_loss_total = 0
current_liquidity = initial_liquidity
initial_price = eth_data['Close'].iloc[0]

# Simulate the process
for day in range(time_period_days):
    current_price = eth_data['Close'].iloc[day]
    
    # Calculate fees earned for the day
    daily_fees = trading_volume_per_day * fee_percentage
    fees_earned += daily_fees
    
    # Check if price is within the range
    lower_bound = initial_price * (1 - price_range)
    upper_bound = initial_price * (1 + price_range)
    
    # Rebalancing code: Check how exactly to do it 
    if not (lower_bound <= current_price <= upper_bound):
        # Price out of range, rebalance
        price_ratio = current_price / initial_price
        il = impermanent_loss(price_ratio)
        impermanent_loss_total += il
        
        # Update liquidity position
        current_liquidity += fees_earned  # Add earned fees to liquidity
        fees_earned = 0  # Reset daily fees
        initial_price = current_price  # Update price for new range

# Final calculation of returns
net_earnings = current_liquidity + fees_earned - initial_liquidity - impermanent_loss_total

# Display results
results = {
    "Initial Liquidity (ETH)": initial_liquidity,
    "Final Liquidity (ETH)": current_liquidity,
    "Total Fees Earned (ETH)": fees_earned,
    "Impermanent Loss (ETH)": impermanent_loss_total,
    "Net Earnings (ETH)": net_earnings
}

results_df = pd.DataFrame(results, index=[0])
print(results_df)
# Out:
# 90
#    Initial Liquidity (ETH)  Final Liquidity (ETH)  Total Fees Earned (ETH)  \
# 0                       10               267010.0                   3000.0
#
#    Impermanent Loss (ETH)  Net Earnings (ETH)
# 0                 0.01734        269999.98266

# %%
import numpy as np
import math

def impermanent_loss(r):
    return 1 - math.sqrt((4 * r) / ((r + 1) ** 2))

def fees_earned(initial_value, fee_percentage, volume):
    return initial_value * fee_percentage * volume

def simulate_liquidity_provision(initial_price, lower_bound, upper_bound, fee_percentage, time_period_months, price_changes, daily_volume_multiple):
    current_price = initial_price
    total_fees = 0
    total_value = initial_value = 1000  # Initial liquidity value in USD

    for day in range(time_period_months * 30):
        # Simulate price movement for the day
        current_price *= price_changes[day]

        if lower_bound <= current_price <= upper_bound:
            # Within range: earn fees
            daily_volume = initial_value * daily_volume_multiple
            daily_fees = fees_earned(initial_value, fee_percentage, daily_volume)
            total_fees += daily_fees
            total_value += daily_fees
        else:
            # Out of range: rebalance
            price_ratio = current_price / initial_price
            il = impermanent_loss(price_ratio)
            total_value = total_value * (1 - il)
            total_value += total_fees  # Reinvest fees earned so far
            total_fees = 0  # Reset fees after rebalancing

            # Rebalance to new range
            lower_bound = current_price * 0.95
            upper_bound = current_price * 1.05
            initial_price = current_price

    return total_value

# Parameters
initial_price = 3000
lower_bound = initial_price * 0.95
upper_bound = initial_price * 1.05
fee_percentage = 0.003  # 0.3% fee
time_period_months = 3
daily_volume_multiple = 0.01  # Assume 1% of initial value traded daily

# Simulate daily price changes (example: small daily fluctuations)
np.random.seed(42)  # For reproducibility
price_changes = 1 + np.random.normal(0, 0.01, time_period_months * 30)  # 1% daily volatility

# Run simulation
final_value = simulate_liquidity_provision(initial_price, lower_bound, upper_bound, fee_percentage, time_period_months, price_changes, daily_volume_multiple)
print(f"Final Value after {time_period_months} months: ${final_value:.2f}")
# Out:
# Final Value after 3 months: $4958.26

# %%
# Uniswap math functions
# https://youtu.be/_asFkMz4zhw?t=25 - Uniswap V3 - Liquidity | DeFi

def get_liquidity_0(x, sp, sb):
    return x * sp * sb / (sb - sp)

def get_liquidity_1(y, sp, sa):
    return y / (sp - sa)

def get_liquidity(x, y, sp, sa, sb):
    if sp <= sa:
        liquidity = get_liquidity_0(x, sp, sb)
    elif sp < sb:
        liquidity0 = get_liquidity_0(x, sp, sb)
        liquidity1 = get_liquidity_1(y, sp, sa)
        liquidity = min(liquidity0, liquidity1)
    else:
        liquidity = get_liquidity_1(y, sp, sa)
    return liquidity


#
# Calculate x and y given liquidity and price range
#
def calculate_x(L, sp, sa, sb):
    sp = max(min(sp, sb), sa)     # if the price is outside the range, use the range endpoints instead
    return L * (sb - sp) / (sp * sb)

def calculate_y(L, sp, sa, sb):
    sp = max(min(sp, sb), sa)     # if the price is outside the range, use the range endpoints instead
    return L * (sp - sa)

def calculate_a1(L, sp, sb, x, y):
    # https://www.wolframalpha.com/input/?i=solve+L+%3D+y+%2F+%28sqrt%28P%29+-+a%29+for+a
    # sqrt(a) = sqrt(P) - y / L
    return (sp - y / L) ** 2

def calculate_a2(sp, sb, x, y):
    # https://www.wolframalpha.com/input/?i=solve+++x+sqrt%28P%29+sqrt%28b%29+%2F+%28sqrt%28b%29++-+sqrt%28P%29%29+%3D+y+%2F+%28sqrt%28P%29+-+a%29%2C+for+a
    # sqrt(a) = (y/sqrt(b) + sqrt(P) x - y/sqrt(P))/x
    #    simplify:
    # sqrt(a) = y/(sqrt(b) x) + sqrt(P) - y/(sqrt(P) x)
    sa = y / (sb * x) + sp - y / (sp * x)
    return sa ** 2

#
# Two different ways how to calculate p_b. calculate_b1() uses liquidity as an input, calculate_b2() does not.
#
def calculate_b1(L, sp, sa, x, y):
    # https://www.wolframalpha.com/input/?i=solve+L+%3D+x+sqrt%28P%29+sqrt%28b%29+%2F+%28sqrt%28b%29+-+sqrt%28P%29%29+for+b
    # sqrt(b) = (L sqrt(P)) / (L - sqrt(P) x)
    return ((L * sp) / (L - sp * x)) ** 2

def calculate_b2(sp, sa, x, y):
    # find the square root of b:
    # https://www.wolframalpha.com/input/?i=solve+++x+sqrt%28P%29+b+%2F+%28b++-+sqrt%28P%29%29+%3D+y+%2F+%28sqrt%28P%29+-+sqrt%28a%29%29%2C+for+b
    # sqrt(b) = (sqrt(P) y)/(sqrt(a) sqrt(P) x - P x + y)
    P = sp ** 2
    return (sp * y / ((sa * sp - P) * x + y)) ** 2



def calculate_P(x,y,sa,sb):
  p = sb*x
  q = y-x*sa*sb
  r = -sb*y
  return (math.pow(-1*q+(q**2 - 4*p*r),0.5)/(2*p) )

def tick_price(t):
  return 1.0001**t

def price_tick(p):
  return math.log(p,1.0001)

def getYFromX(x,sa,sb,sp):
    return x * (sp - sa) * sp *sb /(sb - sp)

# ? P is Y/X
def simulator_calc_L(x,pa,pb,p):
    sa = pa ** 0.5
    sb = pb ** 0.5
    sp = p ** 0.5
    if p >= pb:
        y=x
        x=0
        L = get_liquidity(x, y, sp, sa, sb)
    elif p <= pa:
        y = 0
    else:
        print("sim2", sa, sb, sp, x)
        y = getYFromX(x, sa, sb, sp)
        L = get_liquidity(x, y, sp, sa, sb)

    return L,y

# ! Requires X token to be a stable token
def getXY(capitalDollar, token0Decimals, token1Decimals, Pxusd, Pyusd, sp, sa, sb):
    # captal = x * Pxusd / xdecimals + y * Pyusd / yDecimals  ----- eq1
    # replace y with x from getYFromX

    factor1 = Pxusd / (10 ** token0Decimals)
    factor2 = Pyusd / (10 ** token1Decimals)
    factor3 = (sp - sa) * sp * sb / (sb - sp)

    x = capitalDollar / (factor1 + factor3 * factor2)
    y = getYFromX(x, sa, sb, sp)
    return x, y
